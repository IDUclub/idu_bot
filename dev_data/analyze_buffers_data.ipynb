# %%
import requests
import geopandas as gpd
import pandas as pd

# %%
from elasticsearch import Elasticsearch

ec = Elasticsearch(hosts=[f"http://localhost:9300"])

body = {
    "mappings": {
        "properties": {
            "body_vector": {
                "type": "dense_vector",
                "dims": 4096,
                "index": True,
                "similarity": "cosine",
            },
            "body": {"type": "text"},
            "num_id": {"type": "long"},
            "object_id": {"type": "keyword"},
            "location": {"type": "geo_shape"},
            "properties": {
                "type": "object",
                "enabled": True
            }
        }
    }
}

ec.indices.create(
    index="1830&analyze",
    body=body
)
# Out:
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': '1830&analyze'})

# %%
normative_df = pd.read_excel("ЗОУИТ.xlsx", sheet_name="Загружено в базу")
normative_df = normative_df.dropna(subset="ЗОУИТ").drop(columns=["№", "buffer_type_id", "Буфер (в метрах)", "ID сервиса или физика"])
normative_df.to_parquet("normative_data_cleaned.parquet")

# %%
normative_df = pd.read_parquet("normative_data_cleaned.parquet")

# %%
normative_df
# Out:
#                                                 ЗОУИТ  \
# 0                        Зоны затопления, подтопления
# 5   Санитарно-защитные зоны (СЗЗ), устанавливаемые...
# 9              Придорожная полоса автомобильных дорог
# 12   Охранные зоны объектов электросетевого хозяйства
# 14                       Охранные зоны тепловых сетей
# 16          Охранные зоны газораспределительных сетей
# 18          Охранные зоны магистральных трубопроводов
# 19  Охранные зоны линий и сооружений связи и линий...
#
#                                 Ограничения (строгие)  \
# 0   В границах зон затопления, подтопления запреща...
# 5   В санитарно-защитной зоне запрещается размещен...
# 9   В границах полосы отвода автомобильной дороги ...
# 12  В охранных зонах запрещается осуществлять любы...
# 14  В пределах охранных зон тепловых сетей не допу...
# 16  На земельные участки, входящие в охранные зоны...
# 18  Земельные участки, входящие в охранные зоны тр...
# 19  На трассах радиорелейных линий связи в целях п...
#
#                                     Физический объект  \
# 0                                                Река
# 5                                                 ТБО
# 9                                  Федеральная дорога
# 12                                                ЛЭП
# 14                              Объект теплоснабжения
# 16  Распределительный трубопровод для транспортиро...
# 18                  Объект магистрального газопровода
# 19                                  Сеть электросвязи
#
#              Связанные объекты/сервисы из ограничений
# 0   1) Объекты капитального строительства, не обес...
# 5   1) Жилая застройка, включая отдельные жилые до...
# 9   1) здания, строения, сооружения и другие объек...
# 12  1) Свалка\n 2) хранилища любых, в том числе го...
# 14  1)автозаправочные станции\n 2) хранилища горюч...
# 16  1) объекты жилищно-гражданского и производстве...
# 18  1) свалки\n 2)  берегоукрепительные сооружения...
# 19  1) всякого рода строительные, монтажные и взры...

# %%
all_buffers_resp = requests.get(
    "/api/v1/scenarios/1830/buffers",
    headers=headers
)

from shapely.geometry import shape

df = pd.json_normalize(all_buffers_resp.json()["features"], sep="_")
df["geometry"] = df.apply(lambda x: shape({"type": x["geometry_type"], "coordinates": x["geometry_coordinates"]}), axis=1)
gdf = gpd.GeoDataFrame(df.drop(columns=["geometry_type", "geometry_coordinates", "type", "properties_is_scenario_object", "properties_urban_object_object_geometry_territory_name", "properties_urban_object_object_geometry_territory_id"]).rename(columns={"properties_urban_object_object_geometry_id": "geometry_id", "properties_urban_object_physical_object_type_name": "physical_object_type", "properties_urban_object_physical_object_type_id": "object_type_id", "properties_urban_object_physical_object_name": "physical_object_name", "properties_buffer_type_description": "description", "properties_buffer_type_name": "buffer_type-name"}), geometry="geometry", crs=4326)

# %%
from shapely import union_all

zones_gdf = gpd.GeoDataFrame(gdf.groupby("physical_object_type").agg(
    {
        "buffer_type-name": "first",
        "description": "first",
        "geometry": union_all
    }
).reset_index(), geometry="geometry", crs=4326)
zones_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b0fc7927aabab7dd226588895be28166 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b0fc7927aabab7dd226588895be28166&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b0fc7927aabab7dd226588895be28166 = L.map(
#                 &quot;map_b0fc7927aabab7dd226588895be28166&quot;,
#                 {
#                     center: [60.04437744358522, 30.721380840320926],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_b0fc7927aabab7dd226588895be28166);
#
#
#
#
#
#             var tile_layer_143937b28e0ccf9b1016e474d36222b5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_143937b28e0ccf9b1016e474d36222b5.addTo(map_b0fc7927aabab7dd226588895be28166);
#
#
#             map_b0fc7927aabab7dd226588895be28166.fitBounds(
#                 [[60.03541618997342, 30.70402862821992], [60.05333869719702, 30.73873305242193]],
#                 {}
#             );
#
#
#         function geo_json_6aba4c627127532bad5c29159d59f22e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_6aba4c627127532bad5c29159d59f22e_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_6aba4c627127532bad5c29159d59f22e_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_6aba4c627127532bad5c29159d59f22e_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_6aba4c627127532bad5c29159d59f22e_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_6aba4c627127532bad5c29159d59f22e.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_6aba4c627127532bad5c29159d59f22e_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_6aba4c627127532bad5c29159d59f22e = L.geoJson(null, {
#                 onEachFeature: geo_json_6aba4c627127532bad5c29159d59f22e_onEachFeature,
#
#                 style: geo_json_6aba4c627127532bad5c29159d59f22e_styler,
#                 pointToLayer: geo_json_6aba4c627127532bad5c29159d59f22e_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_6aba4c627127532bad5c29159d59f22e_add (data) {
#             geo_json_6aba4c627127532bad5c29159d59f22e
#                 .addData(data);
#         }
#             geo_json_6aba4c627127532bad5c29159d59f22e_add({&quot;bbox&quot;: [30.70402862821992, 60.03541618997342, 30.73873305242193, 60.05333869719702], &quot;features&quot;: [{&quot;bbox&quot;: [30.70402862821992, 60.035436929280024, 30.73784947758834, 60.05327816182893], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[30.71027518617747, 60.035471870445896], [30.710265829560285, 60.03547431207156], [30.710257604823518, 60.03547762002819], [30.710250828038983, 60.03548166719308], [30.71024

# %%
zones_gdf = zones_gdf.merge(normative_df, how="left", left_on="buffer_type-name", right_on="ЗОУИТ")

# %%
zones_gdf.to_parquet("zones_gdf.parquet")

# %%
list_to_concat = []
for i in (4, 5):
    current_objects = requests.get(
        "/api/v1/scenarios/1830/geometries_with_all_objects",
        params={"physical_object_type_id": i},
        headers=headers
    )
    current_objects_gdf = gpd.GeoDataFrame.from_features(current_objects.json(), crs=4326)
    current_objects_gdf.drop(columns=["territory", "object_geometry_id", "osm_id"], inplace=True)
    list_to_concat.append(current_objects_gdf)

all_objects_gdf = pd.concat(list_to_concat, ignore_index=True)

# %%
all_objects_gdf.sjoin(zones_gdf, how="left").drop(columns=["is_scenario_object", "is_locked", "index_right", "ЗОУИТ", "description", "Физический объект"]).rename(columns={"Связанные объекты/сервисы из ограничений": "На какие объекты влияет зона"})
# Out:
#                                               geometry address  \
# 0    POLYGON ((30.725 60.04121, 30.72533 60.0414, 3...    None
# 1    POLYGON ((30.72542 60.04308, 30.72517 60.0431,...    None
# 2    POLYGON ((30.72483 60.04255, 30.7247 60.04264,...    None
# 3    POLYGON ((30.73406 60.05145, 30.73397 60.05153...    None
# 4    POLYGON ((30.72343 60.04831, 30.72346 60.04833...    None
# ..                                                 ...     ...
# 362  POLYGON ((30.72876 60.04294, 30.72881 60.04293...    None
# 363  POLYGON ((30.72794 60.04437, 30.72801 60.04427...    None
# 364  POLYGON ((30.72482 60.04664, 30.72591 60.047, ...    None
# 365  POLYGON ((30.72104 60.0377, 30.72065 60.03787,...    None
# 366  POLYGON ((30.71083 60.03552, 30.71084 60.03578...    None
#
#                                       physical_objects  \
# 0    [{'physical_object_id': 1474596, 'physical_obj...
# 1    [{'physical_object_id': 1474601, 'physical_obj...
# 2    [{'physical_object_id': 1474606, 'physical_obj...
# 3    [{'physical_object_id': 1474583, 'physical_obj...
# 4    [{'physical_object_id': 1474611, 'physical_obj...
# ..                                                 ...
# 362  [{'physical_object_id': 1474925, 'physical_obj...
# 363  [{'physical_object_id': 1474931, 'physical_obj...
# 364  [{'physical_object_id': 1474937, 'physical_obj...
# 365  [{'physical_object_id': 1474943, 'physical_obj...
# 366  [{'physical_object_id': 1474949, 'physical_obj...
#
#                                               services  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3    [{'service_id': 117290, 'service_type': {'id':...
# 4                                                   []
# ..                                                 ...
# 362                                                 []
# 363                                                 []
# 364                                                 []
# 365                                                 []
# 366                                                 []
#
#         physical_object_type  \
# 0    Промышленная территория
# 1    Промышленная территория
# 2    Промышленная территория
# 3    Промышленная территория
# 4    Промышленная территория
# ..                       ...
# 362  Промышленная территория
# 363  Промышленная территория
# 364  Промышленная территория
# 365  Промышленная территория
# 366                      NaN
#
#                                       buffer_type-name  \
# 0    Санитарно-защитные зоны (СЗЗ), устанавливаемые...
# 1    Санитарно-защитные зоны (СЗЗ), устанавливаемые...
# 2    Санитарно-защитные зоны (СЗЗ), устанавливаемые...
# 3    Санитарно-защитные зоны (СЗЗ), устанавливаемые...
# 4    Санитарно-защитные зоны (СЗЗ), устанавливаемые...
# ..                                                 ...
# 362  Санитарно-защитные зоны (СЗЗ), устанавливаемые...
# 363  Санитарно-защитные зоны (СЗЗ), устанавливаемые...
# 364  Санитарно-защитные зоны (СЗЗ), устанавливаемые...
# 365  Санитарно-защитные зоны (СЗЗ), устанавливаемые...
# 366                                                NaN
#
#                                  Ограничения (строгие)  \
# 0    В санитарно-защитной зоне запрещается размещен...
# 1    В санитарно-защитной зоне запрещается размещен...
# 2    В санитарно-защитной зоне запрещается размещен...
# 3    В санитарно-защитной зоне запрещается размещен...
# 4    В санитарно-защитной зоне запрещается размещен...
# ..                                                 ...
# 362  В санитарно-защитной зоне запрещается размещен...
# 363  В санитарно-защитной зоне запрещается размещен...
# 364  В санитарно-защитной зоне запрещается размещен...
# 365  В санитарно-защитной зоне запрещается размещен...
# 366                                                NaN
#
#                           На какие объекты влияет зона
# 0    1) Жилая застройка, включая отдельные жилые до...
# 1    1) Жилая застройка, включая отдельные жилые до...
# 2    1) Жилая застройка, включая отдельные жилые до...
# 3    1) Жилая застройка, включая отдельные жилые до...
# 4    1) Жилая застройка, включая отдельные жилые до...
# ..                                                 ...
# 362  1) Жилая застройка, включая отдельные жилые до...
# 363  1) Жилая застройка, включая отдельные жилые до...
# 364  1) Жилая застройка, включая отдельные жилые до...
# 365  1) Жилая застройка, включая отдельные жилые до...
# 366                                                NaN
#
# [368 rows x 8 columns]

# %%
from shapely import to_geojson

all_objects_gdf["properties"] = all_objects_gdf.drop(columns="geometry").apply(lambda x: x.to_dict())
all_objects_gdf["location"] = all_objects_gdf["geometry"].apply(to_geojson)
all_objects_gdf["object_id"] = all_objects_gdf["physical_objects"].apply(lambda x: x[0]["physical_object_id"])

# %%
data_do_upload = all_objects_gdf.drop(columns="geometry").to_dict(orient="records")

# %%
index_data = []
for i in data_do_upload:
    row = {
        "text": str(
            {k: v for k, v in i.items() if k not in ("geometry", "physical_objects", "location", "properties")}
        ),
        "object_id": str(i["object_id"]),
        "location": i["location"],
        "properties": i["properties"]
    }
    index_data.append(row)

# %%
index_data[0]["object_id"]
# Out:
# '1474596'

# %%
import json

with open("index_data.json", "w") as f:
    json.dump(index_data, f)
